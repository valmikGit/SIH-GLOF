# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Valmik Belgaonkar\OneDrive\Desktop\SIH-GLOF\sihGlof\resources\glacier_inventory_region_extract.csv', usecols=[' lat', ' lon', ' total_area', ' mean_width', ' mean_depth', ' mean_length', ' max_elev', ' min_elev', ' mean_elev'])

# %%
print(df.columns)
# Out:
# Index([' lat', ' lon', ' total_area', ' mean_width', ' mean_length',
#        ' mean_depth', ' mean_elev', ' max_elev', ' min_elev'],
#       dtype='object')

# %%
df.to_csv('attributes.csv')

# %%
df
# Out:
#           lat     lon total_area mean_width mean_length mean_depth mean_elev  \
# 0      34.672  68.874     1.2800                                        4110
# 1      34.676  68.855     0.3100                                        4350
# 2      34.689  68.854     0.6000                                        4100
# 3      34.707  68.857     0.5600                                        4175
# 4      34.719  68.852     1.0600                                        4050
# ...       ...     ...        ...        ...         ...        ...       ...
# 28819  34.656  75.116     0.0520                 0.2400    10.3400
# 28820  34.641  75.201     0.0290                 0.3100     7.2600
# 28821  34.629  75.192     0.1690                 0.4300    19.9500
# 28822  34.624  75.177     0.2310                 0.8400    22.9200
# 28823  34.620  75.174     0.1680                 0.4400    19.9500
#
#       max_elev min_elev
# 0         4250     3975
# 1         4450     4250
# ...
